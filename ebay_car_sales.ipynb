# %% [markdown]
# # Exploring eBay Car Sales Data
#
# The aim of this project is to clean the data and analyze the included used car listings.
#
# In this guided project, we'll work with a dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website.

# %%
import pandas as pd
import numpy as np # Let's start by importing the libraries we need and reading the dataset into pandas.

autos = pd.read_csv('autos.csv', encoding='Latin-1') # It gives an error with UTF-8, we try with Latin-1 and Windows-1252.

# %%
autos # A neat feature of jupyter notebook is its ability to render the first few and last few values of any pandas object.
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        seller offerType    price   abtest vehicleType  yearOfRegistration  \
# 0      privat   Angebot   $5,000  control         bus                2004
# 1      privat   Angebot   $8,500  control   limousine                1997
# 2      privat   Angebot   $8,990     test   limousine                2009
# 3      privat   Angebot   $4,350  control  kleinwagen                2007
# 4      privat   Angebot   $1,350     test       kombi                2003
# ...       ...       ...      ...      ...         ...                 ...
# 49995  privat   Angebot  $24,900  control   limousine                2011
# 49996  privat   Angebot   $1,980  control      cabrio                1996
# 49997  privat   Angebot  $13,200     test      cabrio                2014
# 49998  privat   Angebot  $22,900  control       kombi                2013
# 49999  privat   Angebot   $1,250  control   limousine                1996
#
#          gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0        manuell      158  andere  150,000km                    3      lpg
# 1      automatik      286     7er  150,000km                    6   benzin
# 2        manuell      102    golf   70,000km                    7   benzin
# 3      automatik       71  fortwo   70,000km                    6   benzin
# 4        manuell        0   focus  150,000km                    7   benzin
# ...          ...      ...     ...        ...                  ...      ...
# 49995  automatik      239      q5  100,000km                    1   diesel
# 49996    manuell       75   astra  150,000km                    5   benzin
# 49997  automatik       69     500    5,000km                   11   benzin
# 49998    manuell      150      a3   40,000km                   11   diesel
# 49999    manuell      101  vectra  150,000km                    1   benzin
#
#             brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0         peugeot              nein  2016-03-26 00:00:00             0
# 1             bmw              nein  2016-04-04 00:00:00             0
# 2      volkswagen              nein  2016-03-26 00:00:00             0
# 3           smart              nein  2016-03-12 00:00:00             0
# 4            ford              nein  2016-04-01 00:00:00             0
# ...           ...               ...                  ...           ...
# 49995        audi              nein  2016-03-27 00:00:00             0
# 49996        opel              nein  2016-03-28 00:00:00             0
# 49997        fiat              nein  2016-04-02 00:00:00             0
# 49998        audi              nein  2016-03-08 00:00:00             0
# 49999        opel              nein  2016-03-13 00:00:00             0
#
#        postalCode             lastSeen
# 0           79588  2016-04-06 06:45:54
# 1           71034  2016-04-06 14:45:08
# 2           35394  2016-04-06 20:15:37
# 3           33729  2016-03-15 03:16:28
# 4           39218  2016-04-01 14:38:50
# ...           ...                  ...
# 49995       82131  2016-04-01 13:47:40
# 49996       44807  2016-04-02 14:18:02
# 49997       73430  2016-04-04 11:47:27
# 49998       35683  2016-04-05 16:45:07
# 49999       45897  2016-04-06 21:18:48
#
# [50000 rows x 20 columns]

# %% [markdown]
# ## Initial Exploration
#
# **USEFUL TOOLS:**
#
# **DataFrame.info()** gives :
# - The total number of rows in the DataFrame.
# - The index range of the DataFrame (start and stop values).
# - The column names and their corresponding data types.
# - The number of non-null values in each column.
# - The memory usage of the DataFrame.
#
# **DataFrame.head():** print the first few rows. Five by default.
#
# **DataFrame.describe():** statistical measures for numeric and categorical (include='all') columns, such as count, mean, standard deviation, minimum, maximum, and quartiles.
#
# **If any columns need a closer look:**
#
# - **Series.head()**
# - **Series.value_counts()**: counts of unique values.

# %%
autos.info()
print('\n')
autos.head() # gives the first five rows by default.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
#  15  notRepairedDamage    40171 non-null  object
#  16  dateCreated          50000 non-null  object
#  17  nrOfPictures         50000 non-null  int64
#  18  postalCode           50000 non-null  int64
#  19  lastSeen             50000 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %% [markdown]
# **Column description:**
# - dateCrawled : when this ad was first crawled, all field-values are taken from this date
# - name : "name" of the car
# - seller : private or dealer
# - offerType
# - price : the price on the ad to sell the car
# - abtest
# - vehicleType
# - yearOfRegistration : at which year the car was first registered
# - gearbox
# - powerPS : power of the car in PS
# - model
# - kilometer : how many kilometers the car has driven
# - monthOfRegistration : at which month the car was first registered
# - fuelType
# - brand
# - notRepairedDamage : if the car has a damage which is not repaired yet
# - dateCreated : the date for which the ad at ebay was created
# - nrOfPictures : number of pictures in the ad
# - postalCode
# - lastSeenOnline : when the crawler saw this ad last online

# %%
autos.describe(include='all') # statistical measures for numeric and categorical (include='all') columns.
# Out:
#                 dateCrawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-04-02 15:49:30  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
# mean                    NaN          NaN     NaN       NaN    NaN    NaN
# std                     NaN          NaN     NaN       NaN    NaN    NaN
# min                     NaN          NaN     NaN       NaN    NaN    NaN
# 25%                     NaN          NaN     NaN       NaN    NaN    NaN
# 50%                     NaN          NaN     NaN       NaN    NaN    NaN
# 75%                     NaN          NaN     NaN       NaN    NaN    NaN
# max                     NaN          NaN     NaN       NaN    NaN    NaN
#
#        vehicleType  yearOfRegistration  gearbox       powerPS  model  \
# count        44905        50000.000000    47320  50000.000000  47242
# unique           8                 NaN        2           NaN    245
# top      limousine                 NaN  manuell           NaN   golf
# freq         12859                 NaN    36993           NaN   4024
# mean           NaN         2005.073280      NaN    116.355920    NaN
# std            NaN          105.712813      NaN    209.216627    NaN
# min            NaN         1000.000000      NaN      0.000000    NaN
# 25%            NaN         1999.000000      NaN     70.000000    NaN
# 50%            NaN         2003.000000      NaN    105.000000    NaN
# 75%            NaN         2008.000000      NaN    150.000000    NaN
# max            NaN         9999.000000      NaN  17700.000000    NaN
#
#          odometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# count       50000         50000.000000    45518       50000             40171
# unique         13                  NaN        7          40                 2
# top     150,000km                  NaN   benzin  volkswagen              nein
# freq        32424                  NaN    30107       10687             35232
# mean          NaN             5.723360      NaN         NaN               NaN
# std           NaN             3.711984      NaN         NaN               NaN
# min           NaN             0.000000      NaN         NaN               NaN
# 25%           NaN             3.000000      NaN         NaN               NaN
# 50%           NaN             6.000000      NaN         NaN               NaN
# 75%           NaN             9.000000      NaN         NaN               NaN
# max           NaN            12.000000      NaN         NaN               NaN
#
#                 dateCreated  nrOfPictures    postalCode             lastSeen
# count                 50000       50000.0  50000.000000                50000
# unique                   76           NaN           NaN                39481
# top     2016-04-03 00:00:00           NaN           NaN  2016-04-07 06:17:27
# freq                   1946           NaN           NaN                    8
# mean                    NaN           0.0  50813.627300                  NaN
# std                     NaN           0.0  25779.747957                  NaN
# min                     NaN           0.0   1067.000000                  NaN
# 25%                     NaN           0.0  30451.000000                  NaN
# 50%                     NaN           0.0  49577.000000                  NaN
# 75%                     NaN           0.0  71540.000000                  NaN
# max                     NaN           0.0  99998.000000                  NaN

# %% [markdown]
# **Exploring individual columns**

# %%
print(autos['nrOfPictures'].value_counts())
# Out:
# 0    50000
# Name: nrOfPictures, dtype: int64

# %% [markdown]
# **Initial data observations:**
#
# - vehicleType, gearbox,  model, fuelType, notRepairedDamage: all of them have some null values.
#
# - The *unique* info from Dataframe.describe() shows that there are several columns with just 2 unique values.: seller, OfferType, abtest, Gearbox and notRepairedDamage.
#
# - 15 columns have string values.
#
# - price and odometer: should be a number for an easier treatment.
#
# - The names of the columns should be homogenus with all caps or lower caps, in order to be easier to work with the data.
# - The 'nrOfPictures' column has not useful values.

# %% [markdown]
# **Cleaning price and odometer columns and converting them to numerical**

# %%
autos['price'] = autos['price'].str.replace('$','').str.replace(',','').astype(int)
print(autos['price'])
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
#          ...
# 49995    24900
# 49996     1980
# 49997    13200
# 49998    22900
# 49999     1250
# Name: price, Length: 50000, dtype: int64

# %%
autos['odometer'] = autos['odometer'].str.replace('km','').str.replace(',','').astype(int)
print(autos['odometer'])
# Out:
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
#           ...
# 49995    100000
# 49996    150000
# 49997      5000
# 49998     40000
# 49999    150000
# Name: odometer, Length: 50000, dtype: int64

# %%
autos = autos.rename({'odometer':'odometer_km'},axis=1)

# %% [markdown]
# **We will continue exploring the odometer and price columns: Removing Outliers**

# %%
print(autos.sort_values('price').loc[52:50,'price'])

# NOTE! REMINDER! If we use .loc the selection corresponds to the labels and indexes, (each row has an index).
# If we use .loc it will print the rows corresponding the indexes from 52 to 50, but it won't work if we want 
# to print the rows from 50 to 52, it is because, since it was sorted (by 'price'), the row with index 50 is 
# positioned below the one with index 52 and not otherwise.
# Out:
# 52       3500
# 32599    3500
# 11709    3500
# 49735    3500
# 13789    3500
#          ...
# 34295    5999
# 11360    5999
# 18238    5999
# 48715    5999
# 50       5999
# Name: price, Length: 7595, dtype: int64

# %%
#print(autos)

# %%
#pd.set_option('display.max_rows', None)

# %%
print(autos.sort_values('price').iloc[50:51, 1]) # We use .iloc in order to print by the position of the rows 
# and not the indexes or labels.
# Out:
# 15203    Opel_Zafira_OPC_LET/LEH_Turbo
# Name: name, dtype: object

# %%
print(autos['price'].value_counts()) # in the output the first column represents the index of the series, 
#which is also the unique 'price' values in the 'autos' dataframe.
# Out:
# 0        1421
# 500       781
# 1500      734
# 2500      643
# 1000      639
#          ...
# 20790       1
# 8970        1
# 846         1
# 2895        1
# 33980       1
# Name: price, Length: 2357, dtype: int64

# %%
print(autos['price'].value_counts().sort_index(ascending=True)) # now we sort the indexes that correspond 
#to the unique price values too.
# Out:
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
#             ...
# 10000000       1
# 11111111       2
# 12345678       3
# 27322222       1
# 99999999       1
# Name: price, Length: 2357, dtype: int64

# %%
print(autos['price'].value_counts().sort_index(ascending=True).tail(20))
# Out:
# 197000      1
# 198000      1
# 220000      1
# 250000      1
# 259000      1
# 265000      1
# 295000      1
# 299000      1
# 345000      1
# 350000      1
# 999990      1
# 999999      2
# 1234566     1
# 1300000     1
# 3890000     1
# 10000000    1
# 11111111    2
# 12345678    3
# 27322222    1
# 99999999    1
# Name: price, dtype: int64

# %% [markdown]
# In order to not remove high prices regarding brands like Ferrari, we will remove as outliers rows of data with prices higher than 10000000.

# %%
print(autos[autos['price'] < 100]['price'].value_counts().sort_index(ascending=True))
print(autos['price'].dtype)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# 20       4
# 25       5
# 29       1
# 30       7
# 35       1
# 40       6
# 45       4
# 47       1
# 49       4
# 50      49
# 55       2
# 59       1
# 60       9
# 65       5
# 66       1
# 70      10
# 75       5
# 79       1
# 80      15
# 89       1
# 90       5
# 99      19
# Name: price, dtype: int64
# int64

# %%
print(autos[(autos['price'] > 0) & (autos['price'] < 100)]['price'].describe())
# Out:
# count    341.000000
# mean      29.105572
# std       32.610455
# min        1.000000
# 25%        1.000000
# 50%       10.000000
# 75%       50.000000
# max       99.000000
# Name: price, dtype: float64

# %% [markdown]
# There are prices that are too low, but for now we will only remove the rows with prices lesser than 100 dolars. Less than 100 dolars for a car seems unrealistic.

# %% [markdown]
# What about the odometer column?

# %%
autos.info() # In order to check the name of the columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  int64
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer_km          50000 non-null  int64
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
#  15  notRepairedDamage    40171 non-null  object
#  16  dateCreated          50000 non-null  object
#  17  nrOfPictures         50000 non-null  int64
#  18  postalCode           50000 non-null  int64
#  19  lastSeen             50000 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 7.6+ MB

# %%
print(autos['odometer_km'].unique())
# Out:
# [150000  70000  50000  80000  10000  30000 125000  90000  20000  60000
#    5000 100000  40000]

# %%
print(autos['odometer_km'].unique().shape)
# Out:
# (13,)

# %%
print(autos['odometer_km'].describe())
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
print(autos['odometer_km'].value_counts())
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %%
print(autos['odometer_km'].value_counts().sort_index(ascending=True))
# Out:
# 5000        967
# 10000       264
# 20000       784
# 30000       789
# 40000       819
# 50000      1027
# 60000      1164
# 70000      1230
# 80000      1436
# 90000      1757
# 100000     2169
# 125000     5170
# 150000    32424
# Name: odometer_km, dtype: int64

# %% [markdown]
# The odometer_km column doesn't appear to have any outlier.

# %% [markdown]
# ## Removing outliers:
#
# We will remove prices lesser than 100 and higher than 9999999:

# %%
# autos = autos[(autos['price'] > 99) & (autos['price'] < 9999999)] we could use this line of code, but instead we 
# will use the between() method.

autos = autos[autos['price'].between(99,9999999)] 
# the between() method checks if the 'price' column falls between the specified values 
# of 99 and 9999999 (inclusive). The between() method returns a boolean Series, 
# which is used to filter the 'autos' DataFrame.

# %%
list_price =list(autos['price'].unique()) # In order to visualize all the values, I convert the unique() output into a list.
list_price.sort(reverse=True) # We sorted the values, to easily check them.
print(list_price)
# Out:
# [3890000, 1300000, 1234566, 999999, 999990, 350000, 345000, 299000, 295000, 265000, 259000, 250000, 220000, 198000, 197000, 194000, 190000, 180000, 175000, 169999, 169000, 163991, 163500, 155000, 151990, 145000, 139997, 137999, 135000, 130000, 129000, 128000, 120000, 119900, 119500, 116000, 115991, 115000, 114400, 109999, 105000, 104900, 99900, 99000, 98500, 94999, 93911, 93000, 89900, 89000, 88900, 86500, 85000, 84997, 84000, 83000, 82987, 80000, 79999, 79980, 79933, 79500, 78911, 76997, 75997, 75900, 75000, 74999, 74900, 73996, 73900, 73500, 72900, 72600, 72500, 71000, 70850, 70000, 69999, 69997, 69993, 69900, 69500, 68900, 68750, 68500, 68300, 68000, 67911, 67000, 66964, 66500, 65990, 65700, 65699, 65000, 64999, 64990, 64900, 64600, 64500, 64280, 63999, 63499, 63000, 62900, 62000, 61999, 61950, 61900, 61500, 60000, 59850, 59500, 59000, 58900, 58700, 58500, 57800, 56900, 56800, 56500, 56000, 55999, 55996, 55900, 55800, 55555, 55500, 55000, 54990, 54500, 53900, 53500, 53000, 52911, 52900, 52500, 52000, 51999, 51990, 51900, 51500, 51000, 50900, 50500, 50000, 49999, 49900, 49500, 49000, 48999, 48900, 48888, 48850, 48700, 48600, 48500, 48490, 48300, 48000, 47997, 47950, 47900, 47800, 47500, 47499, 47000, 46999, 46990, 46911, 46900, 46800, 46500, 46200, 46000, 45950, 45949, 45900, 45800, 45500, 45000, 44996, 44990, 44900, 44777, 44500, 44499, 44497, 44444, 44200, 44000, 43900, 43500, 43461, 43000, 42999, 42996, 42990, 42900, 42800, 42760, 42750, 42500, 42222, 42000, 41999, 41900, 41850, 41800, 41500, 41000, 40999, 40990, 40900, 40850, 40800, 40500, 40499, 40400, 40000, 39999, 39990, 39979, 39911, 39900, 39890, 39800, 39700, 39500, 39300, 39000, 38999, 38990, 38950, 38900, 38850, 38800, 38760, 38700, 38500, 38450, 38400, 38200, 38000, 37999, 37950, 37900, 37850, 37800, 37750, 37700, 37500, 37499, 37480, 37450, 37400, 37300, 37000, 36999, 36900, 36850, 36800, 36675, 36500, 36000, 35999, 35990, 35980, 35950, 35911, 35900, 35890, 35800, 35790, 35700, 35555, 35500, 35499, 35460, 35450, 35370, 35222, 35000, 34999, 34996, 34990, 34980, 34950, 34940, 34900, 34890, 34850, 34800, 34750, 34650, 34550, 34500, 34499, 34490, 34150, 34000, 33999, 33990, 33980, 33950, 33900, 33850, 33800, 33777, 33750, 33700, 33650, 33600, 33500, 33499, 33490, 33449, 33300, 33200, 33000, 32999, 32990, 32950, 32949, 32900, 32800, 32700, 32500, 32490, 32400, 32222, 32150, 32000, 31999, 31990, 31950, 31900, 31800, 31799, 31600, 31500, 31499, 31490, 31450, 31400, 31313, 31200, 31199, 31111, 31000, 30999, 30990, 30987, 30950, 30933, 30900, 30899, 30888, 30800, 30700, 30650, 30570, 30500, 30499, 30400, 30200, 30000, 29999, 29990, 29989, 29980, 29970, 29950, 29900, 29890, 29850, 29800, 29777, 29750, 29700, 29699, 29600, 29550, 29500, 29499, 29490, 29450, 29445, 29400, 29380, 29350, 29333, 29300, 29250, 29200, 29000, 28999, 28990, 28950, 28900, 28850, 28800, 28750, 28700, 28600, 28500, 28499, 28490, 28470, 28450, 28400, 28399, 28300, 28290, 28200, 28000, 27999, 27990, 27950, 27900, 27850, 27800, 27777, 27750, 27700, 27690, 27650, 27600, 27500, 27499, 27490, 27450, 27400, 27350, 27300, 27299, 27280, 27250, 27020, 27000, 26999, 26990, 26950, 26900, 26899, 26850, 26849, 26800, 26750, 26725, 26700, 26660, 26600, 26500, 26499, 26450, 26400, 26390, 26300, 26294, 26250, 26200, 26150, 26000, 25999, 25990, 25987, 25980, 25900, 25880, 25850, 25800, 25750, 25699, 25698, 25650, 25600, 25590, 25500, 25499, 25490, 25450, 25400, 25390, 25350, 25300, 25250, 25200, 25100, 25000, 24999, 24990, 24987, 24980, 24950, 24900, 24895, 24890, 24888, 24850, 24800, 24790, 24750, 24699, 24600, 24550, 24500, 24499, 24490, 24480, 24450, 24444, 24400, 24360, 24350, 24300, 24290, 24242, 24200, 24150, 24000, 23999, 23990, 23989, 23950, 23900, 23899, 23890, 23850, 23800, 23799, 23790, 23750, 23700, 23650, 23600, 23590, 23540, 23500, 23499, 23490, 23450, 23400, 23350, 23333, 23300, 23250, 23233, 23200, 23123, 23000, 22999, 22996, 22990, 22989, 22980, 22950, 22900, 22899, 22890, 22880, 22850, 22800, 22799, ...

# %%
print(autos['price'].value_counts().sort_index(ascending=True).tail(20))
# Out:
# 169999     1
# 175000     1
# 180000     1
# 190000     1
# 194000     1
# 197000     1
# 198000     1
# 220000     1
# 250000     1
# 259000     1
# 265000     1
# 295000     1
# 299000     1
# 345000     1
# 350000     1
# 999990     1
# 999999     2
# 1234566    1
# 1300000    1
# 3890000    1
# Name: price, dtype: int64

# %% [markdown]
# We check that the highest price is equal to 3890000. It makes sense, because it corresponds to the Ferrari brand. There are 3 suspicius values, 999990,999999 and 1234566, we will check them one by one:

# %%
print(autos[autos['price'] == 999990]['name'])
print('\n')
print(autos[autos['price'] == 999999]['name'])
print('\n')
print(autos[autos['price'] == 1234566]['name'])
# Out:
# 37585    Volkswagen_Jetta_GT
# Name: name, dtype: object
#
#
# 514      Ford_Focus_Turnier_1.6_16V_Style
# 43049                       2_VW_Busse_T3
# Name: name, dtype: object
#
#
# 22947    Bmw_530d_zum_ausschlachten
# Name: name, dtype: object

# %% [markdown]
# The so-high prices do not correspond with these three brands and models. For that reason I will remove these three rows:

# %%
autos = autos[(autos['price'] != 999990) & (autos['price'] != 1234566) & (autos['price'] != 999999)]
# another approach is: autos = autos[(autos['price'] < 999990) | (autos['price'] > 1234566)]
# The | symbol means 'or'.

# %%
print(autos['price'].value_counts().sort_index(ascending=True).tail(20))
# Out:
# 163500     1
# 163991     1
# 169000     1
# 169999     1
# 175000     1
# 180000     1
# 190000     1
# 194000     1
# 197000     1
# 198000     1
# 220000     1
# 250000     1
# 259000     1
# 265000     1
# 295000     1
# 299000     1
# 345000     1
# 350000     1
# 1300000    1
# 3890000    1
# Name: price, dtype: int64

# %%
print(autos['price'].value_counts().sort_index(ascending=True).head(20))
# Out:
# 99      19
# 100    134
# 110      3
# 111      2
# 115      2
# 117      1
# 120     39
# 122      1
# 125      8
# 129      1
# 130     15
# 135      1
# 139      1
# 140      9
# 145      2
# 149      7
# 150    224
# 156      2
# 160      8
# 170      7
# Name: price, dtype: int64

# %% [markdown]
# It is interesting to see that 224 cars have a very low price: 150 USD. But as we said, for now, we keep the cars with prices higher than 100 USD.

# %%
print(autos['price'].describe())
# Out:
# count    4.824500e+04
# mean     6.035405e+03
# std      2.073154e+04
# min      9.900000e+01
# 25%      1.250000e+03
# 50%      3.000000e+03
# 75%      7.499000e+03
# max      3.890000e+06
# Name: price, dtype: float64

# %% [markdown]
# ## After removing the price outliers:
#
# We have now a dataframe with price values which range goes from 100 to 3890000 dolars.
# 75% of the cars have prices of less or equal than 7500 dolars.
# 25% of the cars have prices of less or equal than 1250 dolars.

# %% [markdown]
# ## Exploring the date columns
# There are 5 columns that represent different date information.
#
# - `dateCrawled`: added by the crawler
# - `lastSeen`: added by the crawler
# - `dateCreated`: from the website
# - `monthOfRegistration`: from the website
# - `yearOfRegistration`: from the website

# %%
print('dateCrawled: ',autos['dateCrawled'].dtype)
print('lastSeen: ',autos['lastSeen'].dtype)
print('dateCreated: ',autos['dateCreated'].dtype)
print('monthOfRegistration: ',autos['monthOfRegistration'].dtype)
print('yearOfRegistration: ',autos['yearOfRegistration'].dtype)
# Out:
# dateCrawled:  object
# lastSeen:  object
# dateCreated:  object
# monthOfRegistration:  int64
# yearOfRegistration:  int64

# %% [markdown]
# We observe that three of the date columns contain values of string type. To facilitate data manipulation, we intend to convert them into integer format.
#
# First, we are going to print a few rows of each column to examine their structure.

# %%
print(autos['dateCrawled'].head(5))
print('\n')
print(autos['lastSeen'].head(5))
print('\n')
print(autos['dateCreated'].head(5))
print('\n')
print(autos['monthOfRegistration'].head(5))
print('\n')
print(autos['yearOfRegistration'].head(5))
# Out:
# 0    2016-03-26 17:47:46
# 1    2016-04-04 13:38:56
# 2    2016-03-26 18:57:24
# 3    2016-03-12 16:58:10
# 4    2016-04-01 14:38:50
# Name: dateCrawled, dtype: object
#
#
# 0    2016-04-06 06:45:54
# 1    2016-04-06 14:45:08
# 2    2016-04-06 20:15:37
# 3    2016-03-15 03:16:28
# 4    2016-04-01 14:38:50
# Name: lastSeen, dtype: object
#
#
# 0    2016-03-26 00:00:00
# 1    2016-04-04 00:00:00
# 2    2016-03-26 00:00:00
# 3    2016-03-12 00:00:00
# 4    2016-04-01 00:00:00
# Name: dateCreated, dtype: object
#
#
# 0    3
# 1    6
# 2    7
# 3    6
# 4    7
# Name: monthOfRegistration, dtype: int64
#
#
# 0    2004
# 1    1997
# 2    2009
# 3    2007
# 4    2003
# Name: yearOfRegistration, dtype: int64

# %% [markdown]
# We can examine the columns by printing them altogether:

# %%
autos[['dateCrawled','lastSeen','dateCreated']][0:5]
# Out:
#            dateCrawled             lastSeen          dateCreated
# 0  2016-03-26 17:47:46  2016-04-06 06:45:54  2016-03-26 00:00:00
# 1  2016-04-04 13:38:56  2016-04-06 14:45:08  2016-04-04 00:00:00
# 2  2016-03-26 18:57:24  2016-04-06 20:15:37  2016-03-26 00:00:00
# 3  2016-03-12 16:58:10  2016-03-15 03:16:28  2016-03-12 00:00:00
# 4  2016-04-01 14:38:50  2016-04-01 14:38:50  2016-04-01 00:00:00

# %% [markdown]
# We observe that the three columns have the same structure:
# Year-month-day hour:minute:seconds.
#
# **We are going to check the date distributions of the three columns:**

# %%
autos['dateCrawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index() # In order to print only the first 10 characters we use the methoth .str().
# Since after the value_counts() method the dates are the indexes of the series, we can order the data by date by using the sort_index().
# The normalize=True is specified in order to have percentages instead of counts. And dropna=False, is specified to include the null values, so we can check the percentage of null values in that column.
# Out:
# 2016-03-05    0.025371
# 2016-03-06    0.014033
# 2016-03-07    0.036045
# 2016-03-08    0.033206
# 2016-03-09    0.032998
# 2016-03-10    0.032273
# 2016-03-11    0.032604
# 2016-03-12    0.036895
# 2016-03-13    0.015670
# 2016-03-14    0.036646
# 2016-03-15    0.034304
# 2016-03-16    0.029454
# 2016-03-17    0.031527
# 2016-03-18    0.012893
# 2016-03-19    0.034760
# 2016-03-20    0.037786
# 2016-03-21    0.037227
# 2016-03-22    0.032915
# 2016-03-23    0.032294
# 2016-03-24    0.029454
# 2016-03-25    0.031506
# 2016-03-26    0.032314
# 2016-03-27    0.031112
# 2016-03-28    0.034947
# 2016-03-29    0.034097
# 2016-03-30    0.033724
# 2016-03-31    0.031858
# 2016-04-01    0.033703
# 2016-04-02    0.035589
# 2016-04-03    0.038595
# 2016-04-04    0.036584
# 2016-04-05    0.013058
# 2016-04-06    0.003171
# 2016-04-07    0.001389
# Name: dateCrawled, dtype: float64

# %%
autos['lastSeen'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.001078
# 2016-03-06    0.004311
# 2016-03-07    0.005431
# 2016-03-08    0.007317
# 2016-03-09    0.009597
# 2016-03-10    0.010633
# 2016-03-11    0.012395
# 2016-03-12    0.023774
# 2016-03-13    0.008871
# 2016-03-14    0.012623
# 2016-03-15    0.015877
# 2016-03-16    0.016437
# 2016-03-17    0.028086
# 2016-03-18    0.007317
# 2016-03-19    0.015794
# 2016-03-20    0.020665
# 2016-03-21    0.020562
# 2016-03-22    0.021349
# 2016-03-23    0.018593
# 2016-03-24    0.019774
# 2016-03-25    0.019132
# 2016-03-26    0.016665
# 2016-03-27    0.015546
# 2016-03-28    0.020852
# 2016-03-29    0.022282
# 2016-03-30    0.024707
# 2016-03-31    0.023816
# 2016-04-01    0.022842
# 2016-04-02    0.024894
# 2016-04-03    0.025122
# 2016-04-04    0.024541
# 2016-04-05    0.125091
# 2016-04-06    0.221930
# 2016-04-07    0.132097
# Name: lastSeen, dtype: float64

# %%
autos['dateCreated'].str[:10].value_counts(normalize=True, dropna=False).head(40)
# Out:
# 2016-04-03    0.038843
# 2016-03-20    0.037848
# 2016-03-21    0.037455
# 2016-04-04    0.036936
# 2016-03-12    0.036729
# 2016-04-02    0.035278
# 2016-03-14    0.035278
# 2016-03-28    0.035050
# 2016-03-07    0.034781
# 2016-03-29    0.034055
# 2016-03-15    0.034035
# 2016-04-01    0.033682
# 2016-03-19    0.033641
# 2016-03-30    0.033537
# 2016-03-08    0.033206
# 2016-03-09    0.033081
# 2016-03-11    0.032915
# 2016-03-22    0.032729
# 2016-03-26    0.032376
# 2016-03-23    0.032128
# 2016-03-10    0.031983
# 2016-03-31    0.031900
# 2016-03-25    0.031630
# 2016-03-17    0.031195
# 2016-03-27    0.031029
# 2016-03-16    0.029951
# 2016-03-24    0.029392
# 2016-03-05    0.022925
# 2016-03-13    0.017038
# 2016-03-06    0.015297
# 2016-03-18    0.013577
# 2016-04-05    0.011794
# 2016-04-06    0.003254
# 2016-03-04    0.001492
# 2016-04-07    0.001244
# 2016-03-03    0.000871
# 2016-02-28    0.000207
# 2016-02-29    0.000166
# 2016-02-27    0.000124
# 2016-03-02    0.000104
# Name: dateCreated, dtype: float64

# %% [markdown]
# **First observations of the 'dateCrawled', 'lastSeen' and 'dateCreated' columns:**

# %% [markdown]
# - 'dateCrawled': the data was crawled from 2016-03-05 to 2016-04-07.
# - 'lastSeen' : 47% of the ads were last seen from 2016-04-05 to 2016-04-07. The range goes from  from 2016-03-05 to 2016-04-07 as the previous column.
# - 'dateCreated' : the ads were created from 2015-06-11 to 2016-04-07.
# - There are no null values.

# %%
autos['yearOfRegistration'].value_counts().sort_index().head(40)
# Out:
# 1000     1
# 1001     1
# 1111     1
# 1800     2
# 1910     2
# 1927     1
# 1929     1
# 1931     1
# 1934     2
# 1937     4
# 1938     1
# 1939     1
# 1941     2
# 1943     1
# 1948     1
# 1950     1
# 1951     2
# 1952     1
# 1953     1
# 1954     2
# 1955     2
# 1956     4
# 1957     2
# 1958     4
# 1959     6
# 1960    22
# 1961     6
# 1962     4
# 1963     8
# 1964    12
# 1965    17
# 1966    22
# 1967    26
# 1968    26
# 1969    19
# 1970    37
# 1971    26
# 1972    33
# 1973    23
# 1974    24
# Name: yearOfRegistration, dtype: int64

# %%
autos['yearOfRegistration'].value_counts().sort_index().tail(40)
# Out:
# 1990     332
# 1991     338
# 1992     368
# 1993     420
# 1994     627
# 1995    1194
# 1996    1357
# 1997    1929
# 1998    2344
# 1999    2879
# 2000    3105
# 2001    2629
# 2002    2477
# 2003    2694
# 2004    2699
# 2005    2912
# 2006    2669
# 2007    2273
# 2008    2210
# 2009    2080
# 2010    1587
# 2011    1618
# 2012    1309
# 2013     801
# 2014     662
# 2015     381
# 2016    1203
# 2017    1384
# 2018     468
# 2019       2
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       3
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       3
# Name: yearOfRegistration, dtype: int64

# %%
autos[autos['yearOfRegistration'] == 1000]['yearOfRegistration']
# Out:
# 22316    1000
# Name: yearOfRegistration, dtype: int64

# %%
autos['yearOfRegistration'].describe()
# Out:
# count    48245.000000
# mean      2004.729464
# std         87.878422
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: yearOfRegistration, dtype: float64

# %% [markdown]
# The 'yearOfRegistration' column contains registration years that do not correspond to valid years for car registration. The dataframe includes registration years prior to the invention of the first car in 1886, as well as years ranging from 2800 to 9999. The following is a list of these invalid years, along with the number of rows in the dataframe that have each corresponding registration year value:
#
# - 1000 --> 1 row
# - 1001 --> 1 row
# - 1111 --> 1 row
# - 1800 --> 2 rows
# - 2800 -->      1 row
# - 4100 -->      1 row
# - 4500 -->     1 row
# - 4800 -->      1 row
# - 5000 -->      3 rows
# - 5911 -->      1 row
# - 6200 -->      1 row
# - 8888 -->      1 row
# - 9000 -->      1 row
# - 9999 -->      3 rows

# %% [markdown]
# **We will consider the years between 1910 and 2019 as valid for the 'yearOfRegistration' column:**

# %%
autos = autos[(autos['yearOfRegistration'] >= 1910) & (autos['yearOfRegistration'] <= 2019)]

# %%
autos['yearOfRegistration'].value_counts().sort_index().head(10)
# Out:
# 1910    2
# 1927    1
# 1929    1
# 1931    1
# 1934    2
# 1937    4
# 1938    1
# 1939    1
# 1941    2
# 1943    1
# Name: yearOfRegistration, dtype: int64

# %%
autos['yearOfRegistration'].value_counts().sort_index().tail(10)
# Out:
# 2010    1587
# 2011    1618
# 2012    1309
# 2013     801
# 2014     662
# 2015     381
# 2016    1203
# 2017    1384
# 2018     468
# 2019       2
# Name: yearOfRegistration, dtype: int64

# %%
autos['yearOfRegistration'].describe()
# Out:
# count    48226.000000
# mean      2003.489093
# std          7.511783
# min       1910.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       2019.000000
# Name: yearOfRegistration, dtype: float64

# %% [markdown]
# We now have a dataframe of 48230 rows. With registration years that go from 1910 to 2019. Most of the cars had been registered before 2008. The majority of the cars fall within the range from 1999 to 2008.

# %%
print('Brands: ',autos['brand'].unique())
print('\n')
print('Number of brands: ',len(autos['brand'].unique()))
# Out:
# Brands:  ['peugeot' 'bmw' 'volkswagen' 'smart' 'ford' 'chrysler' 'seat' 'renault'
#  'mercedes_benz' 'audi' 'sonstige_autos' 'opel' 'mazda' 'porsche' 'mini'
#  'toyota' 'dacia' 'nissan' 'jeep' 'saab' 'volvo' 'mitsubishi' 'jaguar'
#  'fiat' 'skoda' 'subaru' 'kia' 'citroen' 'chevrolet' 'hyundai' 'honda'
#  'daewoo' 'suzuki' 'trabant' 'land_rover' 'alfa_romeo' 'lada' 'rover'
#  'daihatsu' 'lancia']
#
#
# Number of brands:  40

# %% [markdown]
# 'sonstige_autos' in english means 'other autos', we are going to check the prices and the brands for this especific 'brand':

# %%
autos[autos['brand'] == 'sonstige_autos']['name'].unique()
# Out:
# array(['Corvette_C3_Coupe_T_Top_Crossfire_Injection',
#        'Ssangyong_Actyon_SUV_2.0_xdi2wd_55000_km', 'Ssanyong_Rexton_2.7',
#        'MG_MGB_GT', '3_Fahrzeug_zu_Verkaufen',
#        'Dodge_Nitro_4.0_Automatik_R/T', 'Proton_PKW',
#        'Gut_erhaltene_Alufelgen', 'Wartburg_1.3',
#        'Werkaufen_meine_Iveco_deily', 'Pontiac_Firebird',
#        'Cadillac_SRX_3.6_V6_AWD',
#        'Pontiac_Firebird_3.4___org._30.000_km___LPG',
#        'Pontiac_Firebird_2_8L_V6_Targa__Tuev_07/2016',
#        'Andere_russ._LuAZ_967M_Schwimmwagen_NVA_GSSD_aehnl_GAZ46',
#        'Buick_Riviera', 'Wartburg_353',
#        'Dodge__RAM_Laramie_1500_V8_HEMI_Crew_Cab_AHK',
#        '1936_Daimler_Fifteen_Special_Projekt',
#        'Dodge_RAM_B300_Mowag_Mowag_Dodge_V8_selten_Neuaufbau_US_Car_Van',
#        'DKW_1000_S_Coupe', 'VW_SHARAN_TDI_1.9_TOP_ZUSTAND', 'MG_MGF_1.8i',
#        'MICROCAR_M.GO_Dynamic_Mopedauto_Leichtkraftfahrzeug_NEU',
#        'Cadillac_Deville',
#        'Verkaufe_unser_Wohnmobilbegleitfahrzeug_mit_Transportanhaenger',
#        'Wartburg_353_W', 'Dodge_Nitro_2.8_CRD_DPF_Automatik_SXT_4x4',
#        'Super_Seven_VM_Cosworth_16V_Speedster___plus_Scheibe_Dach_Tueren',
#        'Abarth_500',
#        'Dodge_Custom_880__Black_Plate__Absolute_Raritaet!!!!',
#        'Hanomag_rekord_15k_Suche_ersatz_teile',
#        'Ferrari_348_TB___Original_Zustand', 'Iveco__I__LKW_Geschl.Kasten',
#        'Maserati_Quattroporte_DuoSelect', 'Melkus_RS1000_GT_Nr_129',
#        'Dodge_Nitro', 'Triumph_TR6_Vergaser_95_PS_dunkelblau',
#        'Alpina_B3_3.3__Baunr._215_/_275_Scheckheftgepflegt_Sommerfahrzeug',
#        'Golf_3_top_preis_mach_ich_noch_bisschen_runter_!!',
#        'Suche_ein_Auto', 'Maserati_Ghibli_Automatik_S_Q4',
#        'Brilliance_BS4', 'Buick_Skylark_Cabrio_V8_1972',
#        'Ich_suche_ein_Auto_bis_300_Euro', 'Reddbeat1976',
#        'KNUTSCHKUGEL_2_JAHRE_TÜV',
#        'Cadillac_Deville_Luxury_6_Sitzer_Business_Mega_Voll',
#        'Pfau__Multicar___Winterdienstfahrzeug_Neuer_TÜV_Bis_Dez._2017',
#        'Suche_Kleinwagen_bis_Maximal_1200\x80', 'NSU_Andere',
#        'Pfau__Multicar___Winterdienstfahrzeug', 'GMC_Sierra', 'Dodge_RAM',
#        'Combi_gesucht', 'Strandbuggy_mit_Zulassung',
#        'Pontiac_Firebird_Automatik',
#        'Triumph_TR6__ungeschweisster_Roadster_Tuev_09/17',
#        'Talbot__Simca__Solara_GL', 'Elektroauto_CityEL_Factfour_48V',
#        'Maserati_222', 'AC_Cobra_427_V8_Replika',
#        'Dodge_Grand_Caravan_SXT', 'Verkaufe_zwei_Fahrzeuge',
#        'Iveco_Daily_Bus_TÜV_neu_LKW_Zulassung__kein_ducato__transit',
#        'Borgward_isabella_restauration_Guenstiger_Oldtimer_Winterprojekt',
#        'NSU_Prinz_4', 'Iveco_75_E14', 'Wartburg_1.3__kein_Trabant',
#        'YA126_DAF_Berge__Werstatt_und_Manschaft_Wagen',
#        'Ssangyong_Kyron_200_Xdi_4x2_Automatik', 'Abarth_Punto_Evo',
#        'Lexus_IS_200', 'Ssangyong_Rexton_2_7_dci_tuev_neu', 'Ferrari_F40',
#        'Pontiac_Trans_Am', 'Andere_Andere_GAZ_Sobol', 'Mopedauto_Aixam',
#        'Gmc_vandura', 'GMC_Vandura__TÜV_neu__SoKFZ_Buerofahrzeug',
#        'Bentley_Continental_Flying_Spur_Speed',
#        'Suche_ein_auto_bis_500_euro_ab_bj_2000', 'Plymouth_Andere',
#        'Barkas_B1000__2Takter_Fensterbus__Partybus__Wohnmobil',
#        'Lexus_400_h_Luxory', 'Verkaufe_Polo_Farbe_rot', 'Andere_Andere',
#        'Cadillac_BLS_1.9_D_DPF_Automatik_Elegance', 'Pontiac_Bonneville',
#        'Asia_Motors_Rocsta_Hardtop_cabrio', 'Dodge_Ramcharger',
#        'Oldsmobil_Diesel_delta_selten_v_8_diesel',
#        'Sehr_schoener_Plymouth_Savoy', 'Dodge_Magnum',
#        'MOPEDAUTO_Ligier_X_Too_Leichtkraftfahrzeug_45kmh_MOFAAUTO_45_kmh',
#        'Ssangyong_Korando_2.0_4WD',
#        'Corvette_Corvette_Coupe_C6_6_2_V8_AT_Performance',
#        'Cadillac_Seville_STS_32V_Northstar_300_PS_Ideal_als_Teiletraeger',
#        'Wartburg_311_zu_verkaufen', 'Rohkaraosserie_MG_B_GT',
#        'Lexus_IS_250_Aut._Sport_Line', 'MG_Midget',
#        'Andere_Simca_5_Fourgonette_Kombilimousine', 'LEXUS_IS_200',
#        'Liegnitzer_Strasse', 'Proton_415._TÜV_bis_03/16',
#        'MGF_Roadster_2002_RHD_Kopfdichtung_durch',
#        'Dodge_Caliber_2.0_CVT_SXT',
#        'Strandbuggy/_Borossi_Joyner_BB_1100_Strassenzulassung/_Funfahrzeug',
#        'Isuzu_Single_Cab_4x2_MJ_2011_Schneeschild',
#        'Dodge_Journey_2.0_CRD_SXT',
#        'Original__Lamborgini_Diablo_Schutzhaube_91_2002',
#        'Lincoln_Town_Car', 'Wohnwagen_LMC__10_2009', 'Triumph_Spitfire',
#        'Andere_Elektromobil_City_El_Fact_Four',
#        'Andere_Citycom_Cityel_Fact_4_mit_original_289_km',
#        'Ssangyong_Rexton_W_2.0_D20_DTR_4WD', 'Pontiac_Grand_Le_Mans',
#        'Lexus_LS_430_President_Line"Keyless"softclose_Navi',
#        'Dodge_Caliber_1.8_SE__8Fach_AHK_Klima_Scheckheft_Tuev_SUV_Daimler',
#        'Ssangyong_Rexton_RX_270_XVT', 'Ssangyong_Kyron_Xdi_4WD_Automatik',
#        'Maserati_Ghibli_bj94_306_ps_biturbo_mit_deutscher_zulassung!',
#        'Mopedauto_Chatenet_Stella', 'Andere_Panhard_PL_17',
#        'Opel_Corsa_B__4_Tuerer_zu_verkaufen', 'Chevrolet_matiz_1_0',
#        'Andere__Buggy_Quadix/XYJK800', 'Iveco_35_S_13_V_L_Cool_TÜV_NEU',
#        'Beach_Buggy_Apal', 'MG_MG_TF_135',
#        'Lexus_IS_200_Sport_Standheizung_Top',
#        'Suche_guenstiges_Auto_automatik', 'NSU_Oldtimer_Bj._1960',
#        'Aixam_Crossline',
#        'Triumph_TR4A_IRS_\x96_1965___original_/_unrestored',
#        'Wartburg_Wartburg_1.3', 'Rolls_Royce_Phantom_Drophead_Coupe',
#        'ALPINA_D3_Touring', 'Lexus_IS_220d_DPNR___Executive',
#        'Lexus_IS_250_Sport_Line', 'Dodge_grand_Caravan',
#        'London_Taxi___Austin_FX4___Ersatzteilespender___Motor_dreht',
#        'Suche_schwarzes_Auto', 'Suche_Anfaengerauto',
#        'Kleines_Auto_mit_Tuev',
#        'Fahrzeug_Marke:_Proton_Tuev_04/16_Mizub._Power',
#        'Bentley_Continental_GTC', 'Piaggio_Porter',
#        'Suche_sparsames_Auto!', 'MG_MGB',
#        'Abarth_595C_Tourismo_/_Automatik_/_Traumzustand_/_Mwst/',
#        'Dodge_Challenger', 'Barkas_B1000__1__Viertakt_motor',
#        'Vw_Golf_4_Sport', 'Bentley_Continental_Supersports',
#        'Cadillac_CTS_V_Dt.Modell_Garantie_3/17_Magnaflow_Winter.',
#        'DODGE_RAM_1500_HEMI_LONGBED_selten_Top_Zustand_9x17',
#        'Morgan_Andere', 'Lexus_CT_200h_Dynamic_Line', 'Hummer_H2',
#        'Pontiac_Trans_Am_V8__Targa', 'HYSOUNG_Karion_RT_125ccm',
#        'Talbot_Tagora', 'Maserati_Biturbo',
#        'Dodge_Ram_5.7_Hemi_1500_Long_bed_4x4', 'Suche_Pkw_mit_TÜV',
#        'VW_Touran',
#        'FREEWIEL_SHUTTLE_Invalidenfahrzeug_KRANKENFAHRSTUHL_Mopedauto',
#        '2er_pferdeanhaenger_boeckmann', 'MG_MGB_GT_MK_III_1.8l',
#        'Dodge_Dakota', 'Suche_PKW_mit_1_Jahr_TÜV',
#        'Pontiac_Trans_Sport_GMC_Mot__USA_',
#        'Iveco_Sprinter_3_5t_weiss_Park_Hilfe_Kamera',
#        'maserati_spyder._Raucherfahrzeug.',
#        'GMC_Vandura_Chevrolet_G20_Womo_Standh_Ahk_A_Team',
#        'Abarth_Grande_Punto', 'Saangyong_muso',
#        'Abarth_500_Abarth_Vollausstattung__1.Hand__Scheckheft',
#        'Ich_besorge_Ihnen_ihr_naechstes_Auto',
#        'Lexus_CT_200h_Executive_Line', 'Microcar_Virgo_2_45_kmh',
#        'Massey_Ferguson_MF35_FE35_Traktor_Trecker_Diesel_Oldtimer',
#        'Dodge_RAM_1500_SLT_5_9l_V8_4X4_Benzin_/_Gas',
#        'Dodge_Journey_2.4_SE._Automatik__7_Sitzer__3_Zonen_KA.',
#        'Corvette_C3__Oldtimer_Abnahme_und_original_87000_KM',
#        'Dodge_D_200_H_Zulassung!!!', 'Ssangyong_Musso_E23',
#        'Proton_mit_TÜV_bis_09/2106_mit_ALU_reifen',
#        'Dodge_RAM_Sport__Hemi__4x4',
#        'Biete_312_Wartburg_Limousine__Baujahr_05/1959',
#        'MAZDA_KNUTSCHKUGEL....TÜV_NEU', 'Auto_gesucht!',
#        'Plymouth_Plymouth_Roadrunner_Clone_1969',
#        'Cadillac__Sedan_de_Ville', 'Triumph_TR3_A',
#        'Cadillac_Deville_DTS_4.6_Night_Vision_Infrarot_System__LED_',
#        'MG_MGF_1.8i_VVC_/_Suplex_Fahrwerk',
#        'Ssangyong_Actyon_SUV_bj_2008_55000km', 'Maserati_4200',
#        'Rolls_Royce_Silver_Spur', 'Suche_BAUSTELLENAUTO',
#        'Hummer_H2__6_0l__Leder__Bose__AHK__guter_Zustand',
#        'Wartburg_Andere',
#        'Tesla_Model_X90D_Autopilot_Leder_AHK_Kaltwetter´_Paket',
#        'Verkaufe_Dodge_Durango_5.2_Magnum_SLT',
#        'Dodge_RAM_1500_Quad_CAB_HEMI_SLT',
#        'MG_Mercedes_C_180_mit_2_Jahren_TÜV_._bis_2018_Maerz.',
#        'MG_MGF_1.8i_LIMITED_EDITION', 'AC_Andere', 'Oldtimer__IFA_F9',
#        'Abarth_OT_1000_Replica_auf_850_Special_m._H_Kennzeichen',
#        'Dodge_RAM_1500_4_7', 'Cadillac_Fleetwood_7.7_Liter_V8',
#        'Plymouth_Fury_Coupe_1975_mit_orig._16.000_Meilen_318er_V8_TÜV_/H',
#        'Lexus_CT_200h', 'Rolls_Royce_Camargue', 'Lexus_GS_300_Edition',
#        'piaggio_Porter_mit_Motorschaden',
#        'Corvette_Corvette_C4_5_7_LT1_Jubilaeumsmod.40Jahre_2.Hd',
#        'Andere_DKW_F8_Cabrio_Limosine', 'Transporter_gesucht',
#        'Opel_Corsa___1_2__16_V_', 'Auto_gesucht', 'Maserati_Granturismo',
#        'Lexus_IS_220d_Luxury_Line___Vollausstattung',
#        '25_Km_Auto_ohne_Fuehrerschein',
#        'Morris_Minor_Traveller_Oldtimer__1962__Tacho_3500_mls',
#        'SportSLTQuadCab4x4',
#        'Wartburg_1.3_zwei_Autos__einer_mit_TueV__der_andere_ohne',
#        'Andere_GAZ_Oldtimergelaendewagen_1941',
#        'Oldtimer_Sport___Cabrio_Georges_Irat',
#        'VW_lupo/VW_Polo/Ford_Fiesta/_Opel_Corsa_C',
#        'Mopedauto_Micocar_MC2', 'Maserati_3200_GTA', 'MG_Andere',
#        'Barkas_B_1000_Neu_aufgebaut_im_Top_Zustand',
#        'Willys_Jeep_Replica', 'Aston_Martin_DB7_Vantage_v12',
#        'Suche_bis_max_600_E', 'Maserati_Quattroporte_AM_330_mit_H_Kennz',
#        'Rolls_Royce_Silver_Shadow', 'Suche_dringend_Auto_mit_TÜV',
#        'Maserati_Granturismo_S',
#        'Wir_kaufen_Ihren_Gebrauchten_fuer_einen_sehr_guten_Preis',
#        'Wartburg_Wartburg_353__2_Takter__Oldtimergutachten_',
#        'Dodge_RAM_Einzelstueck',
#        'Triumph_Spitfire__1a__Zustand_!_Osteraktion_bis_26.03.2016!',
#        'Tesla_Model_X_P90D_Signature_Sondermodel__Neuwagen_0km',
#        'Spitfire_1500', 'Zu_Verkaufen',
#        '1960_Nash_Metropolitan_Rockabella_Dream_Car_mit_TÜV__und_H_Kennz.',
#        'Wartburg_353W_Frontkuehler___sehr_Gepflegt',
#        'MASERATI_QUATTROPORTE', 'Buggy_250ccm_Projektaufgabe_.',
#        'Buggy_500_ccm_allrad__nur_500_km_gelaufenmit_StrassenZulassung',
#        'Wartburg_311', 'ML_400_AMG___V8', 'Triumph_Spitvire_MK_IV',
#        'Dodge_Viper', 'Suche_Gelaendewagen', 'MG_MGF', 'Piaggio_Ape_50',
#        'Oldsmobile_Vista_Cruiser', 'Suesser_Flitzer', 'Dodge_Durango',
#        'Verkaufe_M_561_Gama_Goat_mit_H_Zulassung_07er_Nummer',
#        'Dodge_ram_van_b250_V8',
#        'Ferrari_360_Modena_F1___von_RONALDO_BRASIL_NOVITEC_TUBI',
#        'ALPINA_B3_Biturbo_Cabrio_Switch_Tronic',
#        'Cadillac_STS_4.6_V8_Sport_Luxury_LPG_Prins', 'ALPINA_D3',
#        'Brilliance_CamPro_1_6_SX_einmalig_in_Deutschland__4550KM',
#        'PROTON_413__4_Tuerig__Mitsubishi_nachbau_', 'MG_MG_ZT_T_2.5_V6',
#        'Cadillac_Escalade_6.2_V8_Sport_Luxury__LPG_Autogas',
#        'Lexus_IS_250_Aut._Sport_Luxury_Line',
#        'Cadillac_Calaise__Deville__top_Zustand',
#        'ALPINA_B10_Bi_Turbo_BiTurbo',
#        'Lincoln_Town_Car_Stretchlimousine_14_Personen_PKWschein',
#        'MG_ZT_MK1_Diesel_131_PS!!!',
#        'Cadillac_Fleetwood_Brougham_Stretchlimousine',
#        '*_Ssyangyong_Rodius_270_XDI_aus_erste_hand_*_AHK__2500_KG_*',
#        'Corvette_C3_Stingray_Targa_mit_H_Kennzeichen',
#        'GMC_Yukon__GMC__GMC_Yukon_Denali__V8__6.0L__SUV__4x4__TAUSCH??',
#        'Cadillac_Deville_Cabrio_Bj_68_H_Kennzeichen_guter_Zustand',
#        'Corvette_Corvette_Coupe_Automatik_Klappenauspuff',
#        'Dodge_RAM_2500_V10_4x4_SLT',
#        'GS_Moon_Strandbuggy_Spezialumbau_extrabreit___alles_eingetragen',
#        'Lotus_Lotus_Elise_S', 'MG_ZS_180_viele_neuteile',
#        'Oldsmobile_Cutlass', '3er_golf',
#        'Ssangyong_korando__Lpg_Gas_2.3_TÜV/AU_11/17_Euro_3_Klima_AHK_Alu',
#        'Suche_Fachwissen_zu_Gutbrod_bus',
#        'Andere_Daf_66_Variomatic_Super_de_Luxe',
#        'Proton_C9_Persona_416_GLXI_Bastlerfahrzeug__Fliessheck',
#        'Piaggio_APE_TM__TÜV_NEU__wenig_Kilometer_!!!',
#        'Dodge_Caliber___schwarz___Automatik___Navi/Sound___8fach_bereift!',
#        'Dodge_Journey_2.0_CRD_DSG_R/T', 'Adly_buggy',
#        'Robur_Bus/Van_20_Sitze_.',
#        'Iveco_35_C_12_V_L_DPF_AGile_Maxi+Hoch+Lang_Zwillingsbe',
#        'Dodge_Caliber_2.0_CRD_SXT_vieles_im_Wert_von_4850\x80_NEU',
#        'Andere_Andere_1969_Chevrolet_Camaro', 'MG_MGF_75_Limited_Edition',
#        'Lexus_IS_220d_DPNR_Luxury_Line', 'Koppelauto_Golf_3',
#        'Oldsmobile_Cutlass_1971_V8', 'Lexus_RX_400h__hybrid__Luxury',
#        'Checker_Cab_US_Taxi', 'V8_Olds_mit_H_Zulassung',
#        'Abarth_500_Esseesse', 'Dodge_Avenger_2.0_SE',
#        'Triumph_GT6_MK1_Traum_zustand!!', 'Dodge_Ram_van', 'ALPINA_B12',
#        'Cadillac_CTS_3.6_AWD_Sport_Xenon_Bose_scheckheft_von_privat',
#        'Export_Haendler', 'Pontiac__Trans_am_Targa',
#        'Plymouth_Roadrunner_Clone',
#        'Ford_Galaxie_500_Cabrio__V8__6.4L__Oldtimer__US_Car_Raritaet',
#        'Reno_clio_mit_2_jahren_TUV',
#        'MAN_LKW_7_5_mit_Kuehlkoffer_EZ_11.1999_Voll_Funktionstuechtig',
#        'Buick_Electra_225_limited_"Osterpreis"_mit_H_Kennzeichen_',
#        'Corvette_C4',
#        'Verkaufe_hier_ein_Mopedauto__Aixam___Mini___Van._45Km/h._Diesel',
#        'Corvette_82er_Collector_Edition__H_Zulassung__2_Besitzer',
#        'ALPINA_touring', 'Suche_Kombi_Benziner_bis_1500_Euro',
#        'ssangyoug_R', 'Andere_GAZ_69M_neues_H_Gutachten', 'Suche_Auto',
#        'Maserati_Quattroporte',
#        'Dodge_1937_Hotrod_Flathead_Scheunenfund_Oldtimer_kein_Ford',
#        'Pontiac_Firebird_Formula_400___Tausch_moeglich!',
#        'Suche_ein_Auto_auf_Ratenzahlung!!',
#        'Andere_Horch_Sachsenring_P2M_Kuebelwagen_DDR_NVA_IFA',
#        'Iveco_daily', 'suche_guenstigen_5_tuerer_mit_TÜV',
#        'Lexus_GS_300_Luxury_Line',
#        'Zastava_750___bj.1967_oldtimer_"fiat_600"', '2_Autos_zum_tauch',
#        'Westfield_Super_Seven',
#        'Corvette_C5__silber_Automatic_V8__5_7L__ALU___4_Rohr_Endtopf',
#        'Buggy_Lucke_260', 'Bentley_Continental_Flying_Spur',
#        'COCA_COLA_TRUCKS', 'Microcar_M_8_&_DCI_Motor_440_ccm',
#        'Lotus_Lotus_Elise_111R_in_ardent_red_MK2_Komo_Tec',
#        'Strandbuggy_buggy_fun_Car_Auto', 'Ape_Piaggio_50_Van',
#        'Suche_Kleinwagen_fuer_die_Arbeit',
#        'ALPINA_B3_3.3_Lim_LÜCKENLOS_SCHECKHEFTGEPFLEGT._Nr_250',
#        'Buick_Reatta_1988_sehr_selten!', 'Hummer_H3',
#        'Cadillac_Eldorado_Cabrio_1985', 'LKW__Verkauf', 'Microcar_MC1',
#        'Cadillac_Fleetwood', 'Cadillac_STS_4_6___LPG___RECHTSLENKER_!',
#        'Cadillac_Escalade', 'Lexus_RX_400_Hybrid_Luxery', 'Iveco_KASTEN',
#        'Suche_kleinen_Pkw_bis_zu_550_euro_mit_?uev',
#        'DKW_F11_Junior/_Oldtimer', 'TVR_Cerbera_4.5',
#        'Lotus_Super_Seven_Caterham_R_500',
#        'Zu_Verkaufen_Munga_mit_Oltimezrulassung', 'Liger_amber_50ccm',
#        'Piaggio_APE_50_Heizung__Winterreifen__Radio', 'Cadillac_STS',
#        'MG_MG_TF_115', 'Corvette_C4__H_Zulassung',
#        'Dodge_Caliber_2.4_SRT4_Turbo_mit_200km!!!!!!!!!!!!!!!!',
#        'MG_MG_ZS_120', 'Ssangyong_Rexton_RX_270_Xdi_Automatik',
#        'Cadillac_Eldorado_Biarritz_Coupé__2._Hand_Originalzustand',
#        'Spassmobil_Lomax_223_Three_Wheeler__3_Raeder__Dreirad_fast_Oldtimer',
#        'Oldtimersammlung_3x_Zastava_1x_Skoda',
#        'MG_ZR__Leder+Winterreifen_', 'Dogde_Nitro_Top_Auto',
#        'MG_MGF_1_8_Cabrio',
#        'Steyr/Puch_Haflinger_700_AP_4x4_BJ_1971_Militaerfahrzeug',
#        'Suche_Auto_mit_TÜV_bis_1000\x80', 'Kit_Car___Lamborghini',
#        'Plymouth_Fury', 'Lexus_RX_300', 'Tesla_Model_S_85_KW',
#        'Suche_Auto_bis_250_Euro',
#        '1969er_Dodge_D200_Pickup_Autom._383cui', 'Ferrari_FXX',
#        'Cadillac_STS_4.6__V8_Luxury_Sport_EU_Version', 'Iveco_Andere',
#        'Auto_bis_1000\x80_gesucht', 'Sang_Yong_mercedes',
#        'Triumph_TR_7_Cabrio_H_Kennzeichen', 'Suche_Kleinwagen!!!',
#        'Caterham_Lotus_Super_Seven_Linkslenker_mit_gruener_Plakette',
#        'Unfallwagen_Motorschaden_Getriebeschaden_Ankauf__Kaufe_Jeden_Pkw',
#        'Aixam_City_Premium__LEDER__45km/h__ab_16_Jahren', 'Triumph_TR3A',
#        'Ssangyong_Rexton_RX_270_Xdi',
#        'Dodge_Unfall_Viper_SRT_10_mit_8.4_Liter__650_PS',
#        'Dodge_Dakota_3.9l_magnum_lpg', 'Aixam_scouty_r_cabrio',
#        'WARTBURG_311_//__Baujahr_1960', 'Corvette_C6',
#        'Lamborghini_Gallardo_LP560_4_E_Gear_"Callisto_Lifting"',
#        'Opel_Corsa_1.2_Schiebedach_Voll_fahrbereit',
#        'Maserati_Ghibli_Diesel_Automatik'], dtype=object)

# %% [markdown]
# We see that there are many different brands, 'sonstige_autos' includes brands like Tesla, Ferrari, Maserati, Cadillac, etc.
# We will check the lowest and highest prices for these 'sonstige_autos':

# %% [markdown]
# We will check the number of counts for each 'name' (for the 'sonstige_autos' data) that corresponds to an especific model of a brand:

# %%
autos[autos['brand'] == 'sonstige_autos']['name'].value_counts(dropna=False).head(40)
# Out:
# Dodge_RAM                                              6
# MG_MGF_1.8i                                            5
# Hummer_H2                                              4
# Dodge_Nitro                                            3
# Abarth_Grande_Punto                                    3
# Cadillac_Deville                                       3
# Suche_ein_Auto                                         3
# Wartburg_353_W                                         2
# NSU_Andere                                             2
# Triumph_TR3_A                                          2
# Lexus_IS_250_Sport_Line                                2
# MG_MGB                                                 2
# Plymouth_Andere                                        2
# Dodge_Caliber_2.0_CVT_SXT                              2
# Piaggio_Porter                                         2
# Pontiac_Bonneville                                     2
# Lexus_IS_220d_DPNR_Luxury_Line                         2
# Abarth_500                                             2
# Dodge_Challenger                                       2
# Wartburg_1.3                                           2
# Triumph_Spitfire                                       2
# Andere_Andere                                          2
# Pontiac_Firebird                                       2
# MG_MG_TF_135                                           2
# Wartburg_Andere                                        2
# ALPINA_B12                                             2
# MG_Andere                                              2
# Lincoln_Town_Car                                       2
# Cadillac_BLS_1.9_D_DPF_Automatik_Elegance              1
# Pontiac_Trans_Am_V8__Targa                             1
# Lexus_GS_300_Luxury_Line                               1
# Ape_Piaggio_50_Van                                     1
# Maserati_Granturismo_S                                 1
# Plymouth_Fury                                          1
# MG_MGF                                                 1
# Cadillac__Sedan_de_Ville                               1
# Cadillac_Fleetwood                                     1
# Corvette_C3__Oldtimer_Abnahme_und_original_87000_KM    1
# Mopedauto_Chatenet_Stella                              1
# Gut_erhaltene_Alufelgen                                1
# Name: name, dtype: int64

# %%
autos[autos['brand'] == 'sonstige_autos']['name'].value_counts(dropna=False).tail(20)
# Out:
# Wir_kaufen_Ihren_Gebrauchten_fuer_einen_sehr_guten_Preis    1
# Lexus_IS_200_Sport_Standheizung_Top                         1
# VW_SHARAN_TDI_1.9_TOP_ZUSTAND                               1
# Iveco_35_S_13_V_L_Cool_TÜV_NEU                              1
# Rohkaraosserie_MG_B_GT                                      1
# MASERATI_QUATTROPORTE                                       1
# Verkaufe_Polo_Farbe_rot                                     1
# Ich_besorge_Ihnen_ihr_naechstes_Auto                        1
# Suche_PKW_mit_1_Jahr_TÜV                                    1
# Abarth_500_Esseesse                                         1
# Suche_Kleinwagen_bis_Maximal_1200                          1
# Corvette_C4                                                 1
# Wartburg_Wartburg_353__2_Takter__Oldtimergutachten_         1
# Gmc_vandura                                                 1
# Maserati_Biturbo                                            1
# Lexus_CT_200h                                               1
# Ferrari_348_TB___Original_Zustand                           1
# Bentley_Continental_Supersports                             1
# Abarth_Punto_Evo                                            1
# Proton_PKW                                                  1
# Name: name, dtype: int64

# %%
autos[autos['brand'] == 'sonstige_autos']['price'].sort_values().head(20)
# Out:
# 35325    100
# 461      100
# 41053    130
# 36282    140
# 11283    199
# 19425    200
# 15996    200
# 13543    250
# 47444    250
# 20420    250
# 359      299
# 39143    300
# 11893    300
# 35591    300
# 4562     300
# 41537    350
# 31295    350
# 24420    370
# 8598     400
# 18541    400
# Name: price, dtype: int64

# %%
autos[autos['brand'] == 'sonstige_autos']['price'].sort_values().tail(20) # We check the highest prices of the brand with the most expensive cars: 'sonstige_autos'
# Out:
# 29237      46900
# 27481      47000
# 33189      48700
# 34589      48850
# 2698       54500
# 40975      55000
# 30121      59850
# 16006      60000
# 49941      62000
# 4045       72600
# 47406      79500
# 8446       79999
# 3283       80000
# 16964     105000
# 49391     109999
# 22060     114400
# 28090     194000
# 14715     345000
# 7814     1300000
# 47634    3890000
# Name: price, dtype: int64

# %% [markdown]
# It is very interesting the span of prices in this 'sonstige_autos' list of prices. It goes from 100 USD to 3890000 USD.

# %%
print(autos[autos['price'] == 1300000]['name'])
print(autos[autos['price'] == 3890000]['name'])
# Out:
# 7814    Ferrari_F40
# Name: name, dtype: object
# 47634    Ferrari_FXX
# Name: name, dtype: object

# %% [markdown]
# *The highest prices make sense, both correspond to the Ferrari brand.*

# %% [markdown]
# **Below, we will check the percentage of the brands of the 'brand' column in the dataset:**

# %%
autos['brand'].value_counts(normalize=True, dropna=False)
# Out:
# volkswagen        0.212976
# bmw               0.108759
# opel              0.108344
# mercedes_benz     0.095923
# audi              0.085991
# ford              0.069589
# renault           0.047858
# peugeot           0.029445
# fiat              0.026044
# seat              0.018911
# skoda             0.016070
# nissan            0.015324
# mazda             0.015261
# smart             0.014308
# citroen           0.014142
# toyota            0.012670
# hyundai           0.009953
# sonstige_autos    0.009414
# volvo             0.009020
# mini              0.008647
# mitsubishi        0.008128
# honda             0.008025
# kia               0.007112
# alfa_romeo        0.006635
# suzuki            0.005889
# porsche           0.005806
# chevrolet         0.005640
# chrysler          0.003484
# dacia             0.002675
# daihatsu          0.002509
# jeep              0.002219
# subaru            0.002074
# land_rover        0.002053
# saab              0.001638
# daewoo            0.001555
# jaguar            0.001493
# rover             0.001348
# trabant           0.001348
# lancia            0.001120
# lada              0.000601
# Name: brand, dtype: float64

# %% [markdown]
# **Mean prices of the brands in the dataframe**

# %% [markdown]
# Even though we have brands with a low percentage of cars in the dataset,  since we have only 40 brands, we don't need to select a subset. We consider that we can perfectly work with all of them.

# %%
# First I will practice with a not very elegant for loop. 
# And afterwards I will repeat the calculus with a more efficient approach.
brands = autos['brand'].unique()

mean_prices_brand = {}

for brand in brands:
    price = 0
    count = 0
    index = -1
    for element in autos['brand']:
        index += 1
        if brand == element:
            price += autos.iloc[index, autos.columns.get_loc('price')] 
            #since .iloc only works with integer positions, I used that method to get the integer position of the price column.
            count +=1 
    mean_prices_brand[brand] = price / count
    
            
print(mean_prices_brand)
# Out:
# {'peugeot': 3086.930281690141, 'bmw': 8307.007435653002, 'volkswagen': 5364.202122480771, 'smart': 3538.344927536232, 'ford': 3756.9919547079858, 'chrysler': 3539.9166666666665, 'seat': 4353.146929824561, 'renault': 2448.8635181975737, 'mercedes_benz': 8570.76869865975, 'audi': 9259.510248372317, 'sonstige_autos': 24016.248898678416, 'opel': 2968.859330143541, 'mazda': 4075.319293478261, 'porsche': 46764.2, 'mini': 10566.824940047962, 'toyota': 5148.0032733224225, 'dacia': 5897.736434108527, 'nissan': 4681.94046008119, 'jeep': 11590.214953271028, 'saab': 3183.493670886076, 'volvo': 4911.680459770115, 'mitsubishi': 3429.8673469387754, 'jaguar': 11844.041666666666, 'fiat': 2806.984076433121, 'skoda': 6394.309677419355, 'subaru': 4019.07, 'kia': 5923.288629737609, 'citroen': 3772.460410557185, 'chevrolet': 6692.60294117647, 'hyundai': 5405.15625, 'honda': 4010.4728682170544, 'daewoo': 1093.6, 'suzuki': 4166.767605633803, 'trabant': 1843.5384615384614, 'land_rover': 18934.272727272728, 'alfa_romeo': 4054.471875, 'lada': 2647.7241379310344, 'rover': 1586.4923076923078, 'daihatsu': 1641.2644628099174, 'lancia': 3240.703703703704}

# %% [markdown]
# *Now I will calculate the mean prices by using fewer lines of code:*

# %%
brands = autos['brand'].unique()

mean_prices_brand = {}

for brand in brands:
    mean_prices_brand[brand] = autos[autos['brand'] == brand]['price'].mean()
    
            
print(mean_prices_brand)
# Out:
# {'peugeot': 3086.930281690141, 'bmw': 8307.007435653002, 'volkswagen': 5364.202122480771, 'smart': 3538.344927536232, 'ford': 3756.9919547079858, 'chrysler': 3539.9166666666665, 'seat': 4353.146929824561, 'renault': 2448.8635181975737, 'mercedes_benz': 8570.76869865975, 'audi': 9259.510248372317, 'sonstige_autos': 24016.248898678416, 'opel': 2968.859330143541, 'mazda': 4075.319293478261, 'porsche': 46764.2, 'mini': 10566.824940047962, 'toyota': 5148.0032733224225, 'dacia': 5897.736434108527, 'nissan': 4681.94046008119, 'jeep': 11590.214953271028, 'saab': 3183.493670886076, 'volvo': 4911.680459770115, 'mitsubishi': 3429.8673469387754, 'jaguar': 11844.041666666666, 'fiat': 2806.984076433121, 'skoda': 6394.309677419355, 'subaru': 4019.07, 'kia': 5923.288629737609, 'citroen': 3772.460410557185, 'chevrolet': 6692.60294117647, 'hyundai': 5405.15625, 'honda': 4010.4728682170544, 'daewoo': 1093.6, 'suzuki': 4166.767605633803, 'trabant': 1843.5384615384614, 'land_rover': 18934.272727272728, 'alfa_romeo': 4054.471875, 'lada': 2647.7241379310344, 'rover': 1586.4923076923078, 'daihatsu': 1641.2644628099174, 'lancia': 3240.703703703704}

# %% [markdown]
# *Effectively, both results are the same.*

# %% [markdown]
# **Now that we have the mean price values, we are going to sort them:**
#
# NOTE:
#
# The sorted() method in Python is introduced as the tool to sort iterable data such as lists, tuples, and dictionaries. However, by default, it only sorts by keys.
#
# To sort a dictionary by its values, a more complex approach using the sorted() method is presented. The key steps are as follows:
#
# a. Pass the dictionary to the sorted() method as the first argument.
#
# b. Use the items() method on the dictionary to retrieve its keys and values as a sequence of tuples.
#
# c. Specify a key function using a lambda function that extracts the values from the tuples. The key function is responsible for defining the sorting criterion.

# %%
sorted_mean_prices_brand = sorted(mean_prices_brand.items(), key = lambda x:x[1])
# The key parameter is set to lambda x: x[1], which specifies that the sorting should be based on the second element (value) of each pair.

# %%
for element in sorted_mean_prices_brand:
    print(element[0],':',element[1] )
# Out:
# daewoo : 1093.6
# rover : 1586.4923076923078
# daihatsu : 1641.2644628099174
# trabant : 1843.5384615384614
# renault : 2448.8635181975737
# lada : 2647.7241379310344
# fiat : 2806.984076433121
# opel : 2968.859330143541
# peugeot : 3086.930281690141
# saab : 3183.493670886076
# lancia : 3240.703703703704
# mitsubishi : 3429.8673469387754
# smart : 3538.344927536232
# chrysler : 3539.9166666666665
# ford : 3756.9919547079858
# citroen : 3772.460410557185
# honda : 4010.4728682170544
# subaru : 4019.07
# alfa_romeo : 4054.471875
# mazda : 4075.319293478261
# suzuki : 4166.767605633803
# seat : 4353.146929824561
# nissan : 4681.94046008119
# volvo : 4911.680459770115
# toyota : 5148.0032733224225
# volkswagen : 5364.202122480771
# hyundai : 5405.15625
# dacia : 5897.736434108527
# kia : 5923.288629737609
# skoda : 6394.309677419355
# chevrolet : 6692.60294117647
# bmw : 8307.007435653002
# mercedes_benz : 8570.76869865975
# audi : 9259.510248372317
# mini : 10566.824940047962
# jeep : 11590.214953271028
# jaguar : 11844.041666666666
# land_rover : 18934.272727272728
# sonstige_autos : 24016.248898678416
# porsche : 46764.2

# %% [markdown]
# As expected, the most expensive 'brands' are 'sonstige_autos' ('sonstige_autos' means 'other autos' in english, and contains very expensive brands as Ferrari or Maserati), and 'porsche'. And the cheapest brands are 'daewoo' and 'rover'.

# %% [markdown]
# **For the 8 most expensive brands we will try to find a correlation between mileage and price:**
#
# NOTE: The prices for Porsche and those listed under 'sonstige_autos' (other brands or especific models) already make sense without further investigation. These high prices appear to be primarily associated with these expensive brands, such as Porsche and the various brands grouped under 'sonstige_autos'. However, we will check for the 8 highest prices ,included the former ones, if there is any correlation with the mileage. Mileage is a potential factor in determining the market value of luxury brands. Mileage can impact the price of a used car, as lower mileage is often associated with better condition and potentially higher value.

# %% [markdown]
# *In order to facilitate the analysis, first of all, we will convert the mean_prices_brand dictionary into a series object, and then into a dataframe object of one column. Afterwards, we will create another series object from a dictionary with the mean mileage for each brand and append that column to the previous dataframe.*

# %%
mpb_series = pd.Series(mean_prices_brand) # we use the pandas Series constructor.
print(mpb_series)
# The keys of the dictionary become the indexes of the series.
# Out:
# peugeot            3086.930282
# bmw                8307.007436
# volkswagen         5364.202122
# smart              3538.344928
# ford               3756.991955
# chrysler           3539.916667
# seat               4353.146930
# renault            2448.863518
# mercedes_benz      8570.768699
# audi               9259.510248
# sonstige_autos    24016.248899
# opel               2968.859330
# mazda              4075.319293
# porsche           46764.200000
# mini              10566.824940
# toyota             5148.003273
# dacia              5897.736434
# nissan             4681.940460
# jeep              11590.214953
# saab               3183.493671
# volvo              4911.680460
# mitsubishi         3429.867347
# jaguar            11844.041667
# fiat               2806.984076
# skoda              6394.309677
# subaru             4019.070000
# kia                5923.288630
# citroen            3772.460411
# chevrolet          6692.602941
# hyundai            5405.156250
# honda              4010.472868
# daewoo             1093.600000
# suzuki             4166.767606
# trabant            1843.538462
# land_rover        18934.272727
# alfa_romeo         4054.471875
# lada               2647.724138
# rover              1586.492308
# daihatsu           1641.264463
# lancia             3240.703704
# dtype: float64

# %%
mpb_dataframe = pd.DataFrame(mpb_series, columns=['mean_price'])

# %%
mpb_dataframe.sort_values('mean_price')
# Out:
#                   mean_price
# daewoo           1093.600000
# rover            1586.492308
# daihatsu         1641.264463
# trabant          1843.538462
# renault          2448.863518
# lada             2647.724138
# fiat             2806.984076
# opel             2968.859330
# peugeot          3086.930282
# saab             3183.493671
# lancia           3240.703704
# mitsubishi       3429.867347
# smart            3538.344928
# chrysler         3539.916667
# ford             3756.991955
# citroen          3772.460411
# honda            4010.472868
# subaru           4019.070000
# alfa_romeo       4054.471875
# mazda            4075.319293
# suzuki           4166.767606
# seat             4353.146930
# nissan           4681.940460
# volvo            4911.680460
# toyota           5148.003273
# volkswagen       5364.202122
# hyundai          5405.156250
# dacia            5897.736434
# kia              5923.288630
# skoda            6394.309677
# chevrolet        6692.602941
# bmw              8307.007436
# mercedes_benz    8570.768699
# audi             9259.510248
# mini            10566.824940
# jeep            11590.214953
# jaguar          11844.041667
# land_rover      18934.272727
# sonstige_autos  24016.248899
# porsche         46764.200000

# %%
# we create the dictionary with the brand and their mean mileage. 
brands = autos['brand'].unique()

mean_mileage_brand = {}

for brand in brands:
    mean_mileage_brand[brand] = autos[autos['brand'] == brand]['odometer_km'].mean()
    
            
print(mean_mileage_brand)
# Out:
# {'peugeot': 127316.9014084507, 'bmw': 132803.62249761677, 'volkswagen': 129059.48787849284, 'smart': 100833.33333333333, 'ford': 124360.8462455304, 'chrysler': 133125.0, 'seat': 122149.12280701754, 'renault': 128279.89601386481, 'mercedes_benz': 131079.76653696498, 'audi': 129604.53339763684, 'sonstige_autos': 90892.07048458149, 'opel': 129527.27272727272, 'mazda': 124959.23913043478, 'porsche': 98375.0, 'mini': 89100.71942446043, 'toyota': 116219.31260229132, 'dacia': 84728.68217054264, 'nissan': 118707.71312584574, 'jeep': 127102.80373831776, 'saab': 143670.88607594935, 'volvo': 138839.0804597701, 'mitsubishi': 127053.57142857143, 'jaguar': 125763.88888888889, 'fiat': 117472.13375796178, 'skoda': 111051.6129032258, 'subaru': 126100.0, 'kia': 112521.86588921283, 'citroen': 120029.32551319648, 'chevrolet': 100514.70588235294, 'hyundai': 107239.58333333333, 'honda': 123397.93281653746, 'daewoo': 121266.66666666667, 'suzuki': 108485.91549295775, 'trabant': 56692.307692307695, 'land_rover': 118333.33333333333, 'alfa_romeo': 131437.5, 'lada': 85000.0, 'rover': 138230.76923076922, 'daihatsu': 115619.8347107438, 'lancia': 123518.51851851853}

# %%
# We convert the dictionary into a series:
mmb_series = pd.Series(mean_mileage_brand)
print(mmb_series)
# Out:
# peugeot           127316.901408
# bmw               132803.622498
# volkswagen        129059.487878
# smart             100833.333333
# ford              124360.846246
# chrysler          133125.000000
# seat              122149.122807
# renault           128279.896014
# mercedes_benz     131079.766537
# audi              129604.533398
# sonstige_autos     90892.070485
# opel              129527.272727
# mazda             124959.239130
# porsche            98375.000000
# mini               89100.719424
# toyota            116219.312602
# dacia              84728.682171
# nissan            118707.713126
# jeep              127102.803738
# saab              143670.886076
# volvo             138839.080460
# mitsubishi        127053.571429
# jaguar            125763.888889
# fiat              117472.133758
# skoda             111051.612903
# subaru            126100.000000
# kia               112521.865889
# citroen           120029.325513
# chevrolet         100514.705882
# hyundai           107239.583333
# honda             123397.932817
# daewoo            121266.666667
# suzuki            108485.915493
# trabant            56692.307692
# land_rover        118333.333333
# alfa_romeo        131437.500000
# lada               85000.000000
# rover             138230.769231
# daihatsu          115619.834711
# lancia            123518.518519
# dtype: float64

# %%
# And then we assign this Series object as a new column in the preious Dataframe:
mpb_dataframe['mean_mileage'] = mmb_series

# %%
mpb_dataframe.sort_values('mean_price')
# Out:
#                   mean_price   mean_mileage
# daewoo           1093.600000  121266.666667
# rover            1586.492308  138230.769231
# daihatsu         1641.264463  115619.834711
# trabant          1843.538462   56692.307692
# renault          2448.863518  128279.896014
# lada             2647.724138   85000.000000
# fiat             2806.984076  117472.133758
# opel             2968.859330  129527.272727
# peugeot          3086.930282  127316.901408
# saab             3183.493671  143670.886076
# lancia           3240.703704  123518.518519
# mitsubishi       3429.867347  127053.571429
# smart            3538.344928  100833.333333
# chrysler         3539.916667  133125.000000
# ford             3756.991955  124360.846246
# citroen          3772.460411  120029.325513
# honda            4010.472868  123397.932817
# subaru           4019.070000  126100.000000
# alfa_romeo       4054.471875  131437.500000
# mazda            4075.319293  124959.239130
# suzuki           4166.767606  108485.915493
# seat             4353.146930  122149.122807
# nissan           4681.940460  118707.713126
# volvo            4911.680460  138839.080460
# toyota           5148.003273  116219.312602
# volkswagen       5364.202122  129059.487878
# hyundai          5405.156250  107239.583333
# dacia            5897.736434   84728.682171
# kia              5923.288630  112521.865889
# skoda            6394.309677  111051.612903
# chevrolet        6692.602941  100514.705882
# bmw              8307.007436  132803.622498
# mercedes_benz    8570.768699  131079.766537
# audi             9259.510248  129604.533398
# mini            10566.824940   89100.719424
# jeep            11590.214953  127102.803738
# jaguar          11844.041667  125763.888889
# land_rover      18934.272727  118333.333333
# sonstige_autos  24016.248899   90892.070485
# porsche         46764.200000   98375.000000

# %% [markdown]
# Based on only this table, we don't see a clear correlation between price and mileage, we should make a scatter plot to look for trends and correlations. There are 6 brands with less than 100000 km, among them, we have 3 brands in the group of the 10 most expensive brands, it does not give much information to make a conclusion. Regarding the 8 most expensive brands, I don't get any conlusions based only in this table either. Two of the most expensive brands have less than 100000 km, however, those brands are tipically expensive.
